# %%
import pandas as pd
data = pd.read_csv('train_set.csv', index_col='Id')
data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 475          120       RL         41.0     5330   Pave   NaN      Reg
# 696           20       RL         54.0    13811   Pave   NaN      IR1
# 219           50       RL          NaN    15660   Pave   NaN      IR1
# 971           50       RL         60.0    10800   Pave   NaN      Reg
# 187           80       RL          NaN     9947   Pave   NaN      IR1
# 724           50       RL         60.0     8172   Pave   NaN      Reg
# 129           60       RL         69.0     7590   Pave   NaN      Reg
# 1155          60       RL          NaN    13700   Pave   NaN      IR1
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
# 1312          20       RL         68.0     8814   Pave   NaN      Reg
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 894           20       RL          NaN    13284   Pave   NaN      Reg
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1168 entries, 475 to 707
# Data columns (total 80 columns):
# MSSubClass       1168 non-null int64
# MSZoning         1168 non-null object
# LotFrontage      955 non-null float64
# LotArea          1168 non-null int64
# Street           1168 non-null object
# Alley            75 non-null object
# LotShape         1168 non-null object
# LandContour      1168 non-null object
# Utilities        1168 non-null object
# LotConfig        1168 non-null object
# LandSlope        1168 non-null object
# Neighborhood     1168 non-null object
# Condition1       1168 non-null object
# Condition2       1168 non-null object
# BldgType         1168 non-null object
# HouseStyle       1168 non-null object
# OverallQual      1168 non-null int64
# OverallCond      1168 non-null int64
# YearBuilt        1168 non-null int64
# YearRemodAdd     1168 non-null int64
# RoofStyle        1168 non-null object
# RoofMatl         1168 non-null object
# ...

# %%
data.MSSubClass.value_counts(dropna=False)
# Out:
# 20     431
# 60     240
# 50     115
# 120     73
# 160     55
# 30      52
# 70      46
# 80      43
# 90      39
# 190     26
# 85      16
# 75      13
# 45      10
# 180      7
# 40       2
# Name: MSSubClass, dtype: int64

# %%
data.LotFrontage.value_counts(dropna=False)
# Out:
# NaN      213
# 60.0     118
# 70.0      54
# 80.0      53
# 50.0      47
# 75.0      38
# 65.0      35
# 85.0      31
# 21.0      21
# 78.0      21
# 90.0      18
# 63.0      15
# 55.0      15
# 73.0      15
# 51.0      14
# 66.0      14
# 68.0      13
# 24.0      13
# 72.0      12
# 64.0      12
# 74.0      12
# 52.0      11
# 67.0      11
# 43.0      11
# 100.0     10
# 34.0      10
# 79.0      10
# 82.0      10
# 69.0      10
# 57.0       9
#         ...
# 87.0       2
# 115.0      2
# 108.0      2
# 83.0       2
# 101.0      2
# 174.0      2
# 47.0       2
# 118.0      2
# 124.0      2
# 116.0      2
# 114.0      2
# 150.0      1
# 182.0      1
# 97.0       1
# 37.0       1
# 33.0       1
# 153.0      1
# 149.0      1
# 46.0       1
# 152.0      1
# 160.0      1
# 122.0      1
# 112.0      1
# 140.0      1
# 38.0       1
# 106.0      1
# 39.0       1
# 144.0      1
# 111.0      1
# 137.0      1
# Name: LotFrontage, Length: 107, dtype: int64
